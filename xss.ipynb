# %%
import os
from statistics import stdev
from scapy.all import sniff, rdpcap, wrpcap

# %%
def analyze_NUM_packets(pkts):
    """
    analyze NUM packets to get target network characteristics
    :param pkts: NUM target packets, TCP/IP only !!!
    :return:
    - "Average Packet Size", the average length of the TCP/IP packet data field (hereinafter referred to as the packet length)
    - "Flow Bytes/s", the data flow rate
    - "Max Packet Length", the maximum packet length
    - "Fwd Packet Length Mean", the average length of packets transmitted in the forward direction
    - "Fwd IAT Min", the minimum value of the inter-packet interval (IAT, inter-arrival time) in the forward direction
    - "Total Length of Fwd Packets", the total length of packets transmitted in the forward direction
    - "Fwd IAT Std", the standard deviation of the value of the inter-packet interval in the forward direction of the packets
    - "Flow IAT Mean", the average value of the batch interval
    - "Fwd Packet Length Max", the maximum length of a packet transmitted in the forward direction
    - "Fwd Header Length", the total length of the headers of packets transmitted in the forward direction
    """

    last_time = None

    total_length = 0
    max_pkt_len = 0
    fwd_pkts_len = []
    fwd_ia_times = []
    fwd_header_len = 0

    for packet in pkts:
        try:
            total_length += len(packet)
            max_pkt_len = max(max_pkt_len, len(packet))
            fwd_pkts_len.append(packet.len)
            if last_time is not None:
                # print(f"a={self.last_time} b={packet.time} d=b-a={packet.time - self.last_time}")
                fwd_ia_times.append(packet.time - last_time)
            last_time = packet.time
            fwd_header_len += packet.ihl * 4 + packet.dataofs * 4
        except Exception as e:
            print(e)
            print(f"can't analyze packet:")
            packet.show()
    try:
        avg_pkt_size = float(round(total_length / len(pkts), 3))
        flow_bytes_per_s = float(
            round(total_length / (pkts[-1].time - pkts[0].time), 3)
        )
        fwd_pkt_mean_len = float(round(sum(fwd_pkts_len) / len(fwd_pkts_len), 3))
        fwd_iat_min = float(round(min(fwd_ia_times) * 1000, 5))
        tot_len_fwd_pkts = sum(fwd_pkts_len)
        fwd_iat_std = float(round(stdev(fwd_ia_times), 5))
        flow_iat_mean = float(round(sum(fwd_ia_times) / len(fwd_ia_times), 5))
        fwd_pkt_max_len = max(fwd_pkts_len)
        # print(len(fwd_ia_times), fwd_ia_times)
        # print("Average Packet Size:", avg_pkt_size)
        # print("Flow Bytes/s:", flow_bytes_per_s)
        # print("Max Packet Length:", max_pkt_len)
        # print("Fwd Packet Length Mean:", fwd_pkt_mean_len)
        # print("Fwd IAT Min:", fwd_iat_min)
        # print("Total Length of Fwd Packets:", tot_len_fwd_pkts)
        # print("Fwd IAT Std:", fwd_iat_std)
        # print("Flow IAT Mean:", flow_iat_mean)
        # print("Fwd Packet Length Max:", fwd_pkt_max_len)
        # print("Fwd Header Length:", fwd_header_len)
        return (
            avg_pkt_size,
            flow_bytes_per_s,
            max_pkt_len,
            fwd_pkt_mean_len,
            fwd_iat_min,
            tot_len_fwd_pkts,
            fwd_iat_std,
            flow_iat_mean,
            fwd_pkt_max_len,
            fwd_header_len,
        )
    except Exception as e:
        print(e)

# %%
def analyze_pcap(pkts, NUM, row_data):
    """
    group and analyze packets by NUM
    :param pkts: target list with packets
    :return: None, put unlabeled data samples at 'row_data' attribute
    """
    n = len(pkts) + 1
    i, j = 0, NUM
    while i + NUM < n:
        print(f"in analyze fn, num={NUM}, i={i}, j={j}")
        row_data.append(analyze_NUM_packets(pkts[i:j]))
        i, j = j, j + NUM

# %%
pcap_to_read = ''


def read_pcap():
    """
    put the .pcap file at 'sniffed_pkts_list' attribute
    :return: None, put the .pcap file at 'sniffed_pkts_list' attribute
    """
    return rdpcap(pcap_to_read)

# %%
def create_csv(y_correct, NUM, row_data, attack_type):
    """
    create local 'csvs/' folder with .csv datasets based on 'pcap_to_read' attribute
    :return: None, create local 'csvs/' folder
    """

    file_name, file_extension = os.path.splitext(pcap_to_read)
    # print(file_name, file_extension)
    new_folder = os.path.join(os.getcwd(), "csvs", attack_type)
    os.makedirs(new_folder, exist_ok=True)
    if row_data:
        with open(
            os.path.join(new_folder, os.path.split(file_name)[-1] + f"_{NUM}_{y_correct}_" + ".csv"), "w"
        ) as f:
            f.write(
                "Average Packet Size,Flow Bytes/s,Fwd Packet Length Mean,Max Packet Length,Fwd IAT Min,Total Length of Fwd Packets,Flow IAT Mean,Fwd IAT Std,Fwd Packet Length Max,Fwd Header Length,Label\n"
            )
            y_correct = str(y_correct) + "\n"
            for tpl in row_data:
                # print(f'row_tuple : {tpl}')
                f.write(",".join([str(e) for e in tpl] + [y_correct]))

# %%
for NUM in [10, 50, 100, 250, 500, 750, 1000, 5000, 10000]:
    pcap_to_read = "datasets_pcaps/xss/xss-tcp-ip-vi-at-9374.pcap"

    sniffed_pkts_list = read_pcap()
    row_data = []
    analyze_pcap(sniffed_pkts_list, NUM, row_data)
    attack_type = "xss"
    y_correct = 1
    create_csv(y_correct, NUM, row_data, attack_type)
# Out:
# in analyze fn, num=10, i=0, j=10
# in analyze fn, num=10, i=10, j=20
# in analyze fn, num=10, i=20, j=30
# in analyze fn, num=10, i=30, j=40
# in analyze fn, num=10, i=40, j=50
# in analyze fn, num=10, i=50, j=60
# in analyze fn, num=10, i=60, j=70
# in analyze fn, num=10, i=70, j=80
# in analyze fn, num=10, i=80, j=90
# in analyze fn, num=10, i=90, j=100
# in analyze fn, num=10, i=100, j=110
# in analyze fn, num=10, i=110, j=120
# in analyze fn, num=10, i=120, j=130
# in analyze fn, num=10, i=130, j=140
# in analyze fn, num=10, i=140, j=150
# in analyze fn, num=10, i=150, j=160
# in analyze fn, num=10, i=160, j=170
# in analyze fn, num=10, i=170, j=180
# in analyze fn, num=10, i=180, j=190
# in analyze fn, num=10, i=190, j=200
# in analyze fn, num=10, i=200, j=210
# in analyze fn, num=10, i=210, j=220
# in analyze fn, num=10, i=220, j=230
# in analyze fn, num=10, i=230, j=240
# in analyze fn, num=10, i=240, j=250
# in analyze fn, num=10, i=250, j=260
# in analyze fn, num=10, i=260, j=270
# in analyze fn, num=10, i=270, j=280
# in analyze fn, num=10, i=280, j=290
# in analyze fn, num=10, i=290, j=300
# in analyze fn, num=10, i=300, j=310
# in analyze fn, num=10, i=310, j=320
# in analyze fn, num=10, i=320, j=330
# in analyze fn, num=10, i=330, j=340
# in analyze fn, num=10, i=340, j=350
# in analyze fn, num=10, i=350, j=360
# in analyze fn, num=10, i=360, j=370
# in analyze fn, num=10, i=370, j=380
# in analyze fn, num=10, i=380, j=390
# in analyze fn, num=10, i=390, j=400
# in analyze fn, num=10, i=400, j=410
# in analyze fn, num=10, i=410, j=420
# in analyze fn, num=10, i=420, j=430
# in analyze fn, num=10, i=430, j=440
# in analyze fn, num=10, i=440, j=450
# in analyze fn, num=10, i=450, j=460
# in analyze fn, num=10, i=460, j=470
# in analyze fn, num=10, i=470, j=480
# in analyze fn, num=10, i=480, j=490
# in analyze fn, num=10, i=490, j=500
# in analyze fn, num=10, i=500, j=510
# in analyze fn, num=10, i=510, j=520
# in analyze fn, num=10, i=520, j=530
# in analyze fn, num=10, i=530, j=540
# in analyze fn, num=10, i=540, j=550
# in analyze fn, num=10, i=550, j=560
# in analyze fn, num=10, i=560, j=570
# in analyze fn, num=10, i=570, j=580
# in analyze fn, num=10, i=580, j=590
# in analyze fn, num=10, i=590, j=600
# in analyze fn, num=10, i=600, j=610
# in analyze fn, num=10, i=610, j=620
# in analyze fn, num=10, i=620, j=630
# in analyze fn, num=10, i=630, j=640
# in analyze fn, num=10, i=640, j=650
# in analyze fn, num=10, i=650, j=660
# in analyze fn, num=10, i=660, j=670
# in analyze fn, num=10, i=670, j=680
# in analyze fn, num=10, i=680, j=690
# in analyze fn, num=10, i=690, j=700
# in analyze fn, num=10, i=700, j=710
# in analyze fn, num=10, i=710, j=720
# in analyze fn, num=10, i=720, j=730
# in analyze fn, num=10, i=730, j=740
# in analyze fn, num=10, i=740, j=750
# in analyze fn, num=10, i=750, j=760
# in analyze fn, num=10, i=760, j=770
# in analyze fn, num=10, i=770, j=780
# in analyze fn, num=10, i=780, j=790
# in analyze fn, num=10, i=790, j=800
# in analyze fn, num=10, i=800, j=810
# in analyze fn, num=10, i=810, j=820
# in analyze fn, num=10, i=820, j=830
# in analyze fn, num=10, i=830, j=840
# in analyze fn, num=10, i=840, j=850
# in analyze fn, num=10, i=850, j=860
# in analyze fn, num=10, i=860, j=870
# in analyze fn, num=10, i=870, j=880
# in analyze fn, num=10, i=880, j=890
# in analyze fn, num=10, i=890, j=900
# in analyze fn, num=10, i=900, j=910
# in analyze fn, num=10, i=910, j=920
# in analyze fn, num=10, i=920, j=930
# in analyze fn, num=10, i=930, j=940
# in analyze fn, num=10, i=940, j=950
# in analyze fn, num=10, i=950, j=960
# in analyze fn, num=10, i=960, j=970
# in analyze fn, num=10, i=970, j=980
# in analyze fn, num=10, i=980, j=990
# in analyze fn, num=10, i=990, j=1000
# in analyze fn, num=10, i=1000, j=1010
# in analyze fn, num=10, i=1010, j=1020
# in analyze fn, num=10, i=1020, j=1030
# in analyze fn, num=10, i=1030, j=1040
# in analyze fn, num=10, i=1040, j=1050
# in analyze fn, num=10, i=1050, j=1060
# in analyze fn, num=10, i=1060, j=1070
# in analyze fn, num=10, i=1070, j=1080
# in analyze fn, num=10, i=1080, j=1090
# in analyze fn, num=10, i=1090, j=1100
# in analyze fn, num=10, i=1100, j=1110
# in analyze fn, num=10, i=1110, j=1120
# in analyze fn, num=10, i=1120, j=1130
# in analyze fn, num=10, i=1130, j=1140
# in analyze fn, num=10, i=1140, j=1150
# in analyze fn, num=10, i=1150, j=1160
# in analyze fn, num=10, i=1160, j=1170
# in analyze fn, num=10, i=1170, j=1180
# in analyze fn, num=10, i=1180, j=1190
# in analyze fn, num=10, i=1190, j=1200
# in analyze fn, num=10, i=1200, j=1210
# in analyze fn, num=10, i=1210, j=1220
# in analyze fn, num=10, i=1220, j=1230
# in analyze fn, num=10, i=1230, j=1240
# in analyze fn, num=10, i=1240, j=1250
# in analyze fn, num=10, i=1250, j=1260
# in analyze fn, num=10, i=1260, j=1270
# in analyze fn, num=10, i=1270, j=1280
# in analyze fn, num=10, i=1280, j=1290
# in analyze fn, num=10, i=1290, j=1300
# in analyze fn, num=10, i=1300, j=1310
# in analyze fn, num=10, i=1310, j=1320
# in analyze fn, num=10, i=1320, j=1330
# in analyze fn, num=10, i=1330, j=1340
# in analyze fn, num=10, i=1340, j=1350
# in analyze fn, num=10, i=1350, j=1360
# in analyze fn, num=10, i=1360, j=1370
# in analyze fn, num=10, i=1370, j=1380
# in analyze fn, num=10, i=1380, j=1390
# in analyze fn, num=10, i=1390, j=1400
# in analyze fn, num=10, i=1400, j=1410
# in analyze fn, num=10, i=1410, j=1420
# in analyze fn, num=10, i=1420, j=1430
# in analyze fn, num=10, i=1430, j=1440
# in analyze fn, num=10, i=1440, j=1450
# in analyze fn, num=10, i=1450, j=1460
# in analyze fn, num=10, i=1460, j=1470
# in analyze fn, num=10, i=1470, j=1480
# in analyze fn, num=10, i=1480, j=1490
# in analyze fn, num=10, i=1490, j=1500
# in analyze fn, num=10, i=1500, j=1510
# in analyze fn, num=10, i=1510, j=1520
# in analyze fn, num=10, i=1520, j=1530
# in analyze fn, num=10, i=1530, j=1540
# in analyze fn, num=10, i=1540, j=1550
# in analyze fn, num=10, i=1550, j=1560
# in analyze fn, num=10, i=1560, j=1570
# in analyze fn, num=10, i=1570, j=1580
# in analyze fn, num=10, i=1580, j=1590
# in analyze fn, num=10, i=1590, j=1600
# in analyze fn, num=10, i=1600, j=1610
# in analyze fn, num=10, i=1610, j=1620
# in analyze fn, num=10, i=1620, j=1630
# in analyze fn, num=10, i=1630, j=1640
# in analyze fn, num=10, i=1640, j=1650
# in analyze fn, num=10, i=1650, j=1660
# in analyze fn, num=10, i=1660, j=1670
# in analyze fn, num=10, i=1670, j=1680
# in analyze fn, num=10, i=1680, j=1690
# in analyze fn, num=10, i=1690, j=1700
# in analyze fn, num=10, i=1700, j=1710
# in analyze fn, num=10, i=1710, j=1720
# in analyze fn, num=10, i=1720, j=1730
# in analyze fn, num=10, i=1730, j=1740
# in analyze fn, num=10, i=1740, j=1750
# in analyze fn, num=10, i=1750, j=1760
# in analyze fn, num=10, i=1760, j=1770
# in analyze fn, num=10, i=1770, j=1780
# in analyze fn, num=10, i=1780, j=1790
# in analyze fn, num=10, i=1790, j=1800
# in analyze fn, num=10, i=1800, j=1810
# in analyze fn, num=10, i=1810, j=1820
# in analyze fn, num=10, i=1820, j=1830
# in analyze fn, num=10, i=1830, j=1840
# in analyze fn, num=10, i=1840, j=1850
# in analyze fn, num=10, i=1850, j=1860
# in analyze fn, num=10, i=1860, j=1870
# in analyze fn, num=10, i=1870, j=1880
# in analyze fn, num=10, i=1880, j=1890
# in analyze fn, num=10, i=1890, j=1900
# in analyze fn, num=10, i=1900, j=1910
# in analyze fn, num=10, i=1910, j=1920
# in analyze fn, num=10, i=1920, j=1930
# in analyze fn, num=10, i=1930, j=1940
# in analyze fn, num=10, i=1940, j=1950
# in analyze fn, num=10, i=1950, j=1960
# in analyze fn, num=10, i=1960, j=1970
# in analyze fn, num=10, i=1970, j=1980
# in analyze fn, num=10, i=1980, j=1990
# in analyze fn, num=10, i=1990, j=2000
# in analyze fn, num=10, i=2000, j=2010
# in analyze fn, num=10, i=2010, j=2020
# in analyze fn, num=10, i=2020, j=2030
# in analyze fn, num=10, i=2030, j=2040
# in analyze fn, num=10, i=2040, j=2050
# in analyze fn, num=10, i=2050, j=2060
# in analyze fn, num=10, i=2060, j=2070
# in analyze fn, num=10, i=2070, j=2080
# in analyze fn, num=10, i=2080, j=2090
# in analyze fn, num=10, i=2090, j=2100
# in analyze fn, num=10, i=2100, j=2110
# in analyze fn, num=10, i=2110, j=2120
# in analyze fn, num=10, i=2120, j=2130
# in analyze fn, num=10, i=2130, j=2140
# in analyze fn, num=10, i=2140, j=2150
# in analyze fn, num=10, i=2150, j=2160
# in analyze fn, num=10, i=2160, j=2170
# in analyze fn, num=10, i=2170, j=2180
# in analyze fn, num=10, i=2180, j=2190
# in analyze fn, num=10, i=2190, j=2200
# in analyze fn, num=10, i=2200, j=2210
# in analyze fn, num=10, i=2210, j=2220
# in analyze fn, num=10, i=2220, j=2230
# in analyze fn, num=10, i=2230, j=2240
# in analyze fn, num=10, i=2240, j=2250
# in analyze fn, num=10, i=2250, j=2260
# in analyze fn, num=10, i=2260, j=2270
# in analyze fn, num=10, i=2270, j=2280
# in analyze fn, num=10, i=2280, j=2290
# in analyze fn, num=10, i=2290, j=2300
# in analyze fn, num=10, i=2300, j=2310
# in analyze fn, num=10, i=2310, j=2320
# in analyze fn, num=10, i=2320, j=2330
# in analyze fn, num=10, i=2330, j=2340
# in analyze fn, num=10, i=2340, j=2350
# in analyze fn, num=10, i=2350, j=2360
# in analyze fn, num=10, i=2360, j=2370
# in analyze fn, num=10, i=2370, j=2380
# in analyze fn, num=10, i=2380, j=2390
# in analyze fn, num=10, i=2390, j=2400
# in analyze fn, num=10, i=2400, j=2410
# in analyze fn, num=10, i=2410, j=2420
# in analyze fn, num=10, i=2420, j=2430
# in analyze fn, num=10, i=2430, j=2440
# in analyze fn, num=10, i=2440, j=2450
# in analyze fn, num=10, i=2450, j=2460
# in analyze fn, num=10, i=2460, j=2470
# in analyze fn, num=10, i=2470, j=2480
# in analyze fn, num=10, i=2480, j=2490
# in analyze fn, num=10, i=2490, j=2500
# in analyze fn, num=10, i=2500, j=2510
# in analyze fn, num=10, i=2510, j=2520
# in analyze fn, num=10, i=2520, j=2530
# in analyze fn, num=10, i=2530, j=2540
# in analyze fn, num=10, i=2540, j=2550
# in analyze fn, num=10, i=2550, j=2560
# in analyze fn, num=10, i=2560, j=2570
# in analyze fn, num=10, i=2570, j=2580
# in analyze fn, num=10, i=2580, j=2590
# in analyze fn, num=10, i=2590, j=2600
# in analyze fn, num=10, i=2600, j=2610
# in analyze fn, num=10, i=2610, j=2620
# in analyze fn, num=10, i=2620, j=2630
# in analyze fn, num=10, i=2630, j=2640
# in analyze fn, num=10, i=2640, j=2650
# in analyze fn, num=10, i=2650, j=2660
# in analyze fn, num=10, i=2660, j=2670
# in analyze fn, num=10, i=2670, j=2680
# in analyze fn, num=10, i=2680, j=2690
# in analyze fn, num=10, i=2690, j=2700
# in analyze fn, num=10, i=2700, j=2710
# in analyze fn, num=10, i=2710, j=2720
# in analyze fn, num=10, i=2720, j=2730
# in analyze fn, num=10, i=2730, j=2740
# in analyze fn, num=10, i=2740, j=2750
# in analyze fn, num=10, i=2750, j=2760
# in analyze fn, num=10, i=2760, j=2770
# in analyze fn, num=10, i=2770, j=2780
# in analyze fn, num=10, i=2780, j=2790
# in analyze fn, num=10, i=2790, j=2800
# in analyze fn, num=10, i=2800, j=2810
# in analyze fn, num=10, i=2810, j=2820
# in analyze fn, num=10, i=2820, j=2830
# in analyze fn, num=10, i=2830, j=2840
# in analyze fn, num=10, i=2840, j=2850
# in analyze fn, num=10, i=2850, j=2860
# in analyze fn, num=10, i=2860, j=2870
# in analyze fn, num=10, i=2870, j=2880
# in analyze fn, num=10, i=2880, j=2890
# in analyze fn, num=10, i=2890, j=2900
# in analyze fn, num=10, i=2900, j=2910
# in analyze fn, num=10, i=2910, j=2920
# in analyze fn, num=10, i=2920, j=2930
# in analyze fn, num=10, i=2930, j=2940
# in analyze fn, num=10, i=2940, j=2950
# in analyze fn, num=10, i=2950, j=2960
# in analyze fn, num=10, i=2960, j=2970
# in analyze fn, num=10, i=2970, j=2980
# in analyze fn, num=10, i=2980, j=2990
# in analyze fn, num=10, i=2990, j=3000
# in analyze fn, num=10, i=3000, j=3010
# in analyze fn, num=10, i=3010, j=3020
# in analyze fn, num=10, i=3020, j=3030
# in analyze fn, num=10, i=3030, j=3040
# in analyze fn, num=10, i=3040, j=3050
# in analyze fn, num=10, i=3050, j=3060
# in analyze fn, num=10, i=3060, j=3070
# in analyze fn, num=10, i=3070, j=3080
# in analyze fn, num=10, i=3080, j=3090
# in analyze fn, num=10, i=3090, j=3100
# in analyze fn, num=10, i=3100, j=3110
# in analyze fn, num=10, i=3110, j=3120
# in analyze fn, num=10, i=3120, j=3130
# in analyze fn, num=10, i=3130, j=3140
# in analyze fn, num=10, i=3140, j=3150
# in analyze fn, num=10, i=3150, j=3160
# in analyze fn, num=10, i=3160, j=3170
# in analyze fn, num=10, i=3170, j=3180
# in analyze fn, num=10, i=3180, j=3190
# in analyze fn, num=10, i=3190, j=3200
# in analyze fn, num=10, i=3200, j=3210
# in analyze fn, num=10, i=3210, j=3220
# in analyze fn, num=10, i=3220, j=3230
# in analyze fn, num=10, i=3230, j=3240
# in analyze fn, num=10, i=3240, j=3250
# in analyze fn, num=10, i=3250, j=3260
# in analyze fn, num=10, i=3260, j=3270
# in analyze fn, num=10, i=3270, j=3280
# in analyze fn, num=10, i=3280, j=3290
# in analyze fn, num=10, i=3290, j=3300
# in analyze fn, num=10, i=3300, j=3310
# in analyze fn, num=10, i=3310, j=3320
# in analyze fn, num=10, i=3320, j=3330
# in analyze fn, num=10, i=3330, j=3340
# in analyze fn, num=10, i=3340, j=3350
# in analyze fn, num=10, i=3350, j=3360
# in analyze fn, num=10, i=3360, j=3370
# in analyze fn, num=10, i=3370, j=3380
# in analyze fn, num=10, i=3380, j=3390
# in analyze fn, num=10, i=3390, j=3400
# in analyze fn, num=10, i=3400, j=3410
# in analyze fn, num=10, i=3410, j=3420
# in analyze fn, num=10, i=3420, j=3430
# in analyze fn, num=10, i=3430, j=3440
# in analyze fn, num=10, i=3440, j=3450
# in analyze fn, num=10, i=3450, j=3460
# in analyze fn, num=10, i=3460, j=3470
# in analyze fn, num=10, i=3470, j=3480
# in analyze fn, num=10, i=3480, j=3490
# in analyze fn, num=10, i=3490, j=3500
# in analyze fn, num=10, i=3500, j=3510
# in analyze fn, num=10, i=3510, j=3520
# in analyze fn, num=10, i=3520, j=3530
# in analyze fn, num=10, i=3530, j=3540
# in analyze fn, num=10, i=3540, j=3550
# in analyze fn, num=10, i=3550, j=3560
# in analyze fn, num=10, i=3560, j=3570
# in analyze fn, num=10, i=3570, j=3580
# in analyze fn, num=10, i=3580, j=3590
# in analyze fn, num=10, i=3590, j=3600
# in analyze fn, num=10, i=3600, j=3610
# in analyze fn, num=10, i=3610, j=3620
# in analyze fn, num=10, i=3620, j=3630
# in analyze fn, num=10, i=3630, j=3640
# in analyze fn, num=10, i=3640, j=3650
# in analyze fn, num=10, i=3650, j=3660
# in analyze fn, num=10, i=3660, j=3670
# in analyze fn, num=10, i=3670, j=3680
# in analyze fn, num=10, i=3680, j=3690
# in analyze fn, num=10, i=3690, j=3700
# in analyze fn, num=10, i=3700, j=3710
# in analyze fn, num=10, i=3710, j=3720
# in analyze fn, num=10, i=3720, j=3730
# in analyze fn, num=10, i=3730, j=3740
# in analyze fn, num=10, i=3740, j=3750
# in analyze fn, num=10, i=3750, j=3760
# in analyze fn, num=10, i=3760, j=3770
# in analyze fn, num=10, i=3770, j=3780
# in analyze fn, num=10, i=3780, j=3790
# in analyze fn, num=10, i=3790, j=3800
# in analyze fn, num=10, i=3800, j=3810
# in analyze fn, num=10, i=3810, j=3820
# in analyze fn, num=10, i=3820, j=3830
# in analyze fn, num=10, i=3830, j=3840
# in analyze fn, num=10, i=3840, j=3850
# in analyze fn, num=10, i=3850, j=3860
# in analyze fn, num=10, i=3860, j=3870
# in analyze fn, num=10, i=3870, j=3880
# in analyze fn, num=10, i=3880, j=3890
# in analyze fn, num=10, i=3890, j=3900
# in analyze fn, num=10, i=3900, j=3910
# in analyze fn, num=10, i=3910, j=3920
# in analyze fn, num=10, i=3920, j=3930
# in analyze fn, num=10, i=3930, j=3940
# in analyze fn, num=10, i=3940, j=3950
# in analyze fn, num=10, i=3950, j=3960
# in analyze fn, num=10, i=3960, j=3970
# in analyze fn, num=10, i=3970, j=3980
# in analyze fn, num=10, i=3980, j=3990
# in analyze fn, num=10, i=3990, j=4000
# in analyze fn, num=10, i=4000, j=4010
# in analyze fn, num=10, i=4010, j=4020
# in analyze fn, num=10, i=4020, j=4030
# in analyze fn, num=10, i=4030, j=4040
# in analyze fn, num=10, i=4040, j=4050
# in analyze fn, num=10, i=4050, j=4060
# in analyze fn, num=10, i=4060, j=4070
# in analyze fn, num=10, i=4070, j=4080
# in analyze fn, num=10, i=4080, j=4090
# in analyze fn, num=10, i=4090, j=4100
# in analyze fn, num=10, i=4100, j=4110
# in analyze fn, num=10, i=4110, j=4120
# in analyze fn, num=10, i=4120, j=4130
# in analyze fn, num=10, i=4130, j=4140
# in analyze fn, num=10, i=4140, j=4150
# in analyze fn, num=10, i=4150, j=4160
# in analyze fn, num=10, i=4160, j=4170
# in analyze fn, num=10, i=4170, j=4180
# in analyze fn, num=10, i=4180, j=4190
# in analyze fn, num=10, i=4190, j=4200
# in analyze fn, num=10, i=4200, j=4210
# in analyze fn, num=10, i=4210, j=4220
# in analyze fn, num=10, i=4220, j=4230
# in analyze fn, num=10, i=4230, j=4240
# in analyze fn, num=10, i=4240, j=4250
# in analyze fn, num=10, i=4250, j=4260
# in analyze fn, num=10, i=4260, j=4270
# in analyze fn, num=10, i=4270, j=4280
# in analyze fn, num=10, i=4280, j=4290
# in analyze fn, num=10, i=4290, j=4300
# in analyze fn, num=10, i=4300, j=4310
# in analyze fn, num=10, i=4310, j=4320
# in analyze fn, num=10, i=4320, j=4330
# in analyze fn, num=10, i=4330, j=4340
# in analyze fn, num=10, i=4340, j=4350
# in analyze fn, num=10, i=4350, j=4360
# in analyze fn, num=10, i=4360, j=4370
# in analyze fn, num=10, i=4370, j=4380
# in analyze fn, num=10, i=4380, j=4390
# in analyze fn, num=10, i=4390, j=4400
# in analyze fn, num=10, i=4400, j=4410
# in analyze fn, num=10, i=4410, j=4420
# in analyze fn, num=10, i=4420, j=4430
# in analyze fn, num=10, i=4430, j=4440
# in analyze fn, num=10, i=4440, j=4450
# in analyze fn, num=10, i=4450, j=4460
# in analyze fn, num=10, i=4460, j=4470
# in analyze fn, num=10, i=4470, j=4480
# in analyze fn, num=10, i=4480, j=4490
# in analyze fn, num=10, i=4490, j=4500
# in analyze fn, num=10, i=4500, j=4510
# in analyze fn, num=10, i=4510, j=4520
# in analyze fn, num=10, i=4520, j=4530
# in analyze fn, num=10, i=4530, j=4540
# in analyze fn, num=10, i=4540, j=4550
# in analyze fn, num=10, i=4550, j=4560
# in analyze fn, num=10, i=4560, j=4570
# in analyze fn, num=10, i=4570, j=4580
# in analyze fn, num=10, i=4580, j=4590
# in analyze fn, num=10, i=4590, j=4600
# in analyze fn, num=10, i=4600, j=4610
# in analyze fn, num=10, i=4610, j=4620
# in analyze fn, num=10, i=4620, j=4630
# in analyze fn, num=10, i=4630, j=4640
# in analyze fn, num=10, i=4640, j=4650
# in analyze fn, num=10, i=4650, j=4660
# in analyze fn, num=10, i=4660, j=4670
# in analyze fn, num=10, i=4670, j=4680
# in analyze fn, num=10, i=4680, j=4690
# in analyze fn, num=10, i=4690, j=4700
# in analyze fn, num=10, i=4700, j=4710
# in analyze fn, num=10, i=4710, j=4720
# in analyze fn, num=10, i=4720, j=4730
# in analyze fn, num=10, i=4730, j=4740
# in analyze fn, num=10, i=4740, j=4750
# in analyze fn, num=10, i=4750, j=4760
# in analyze fn, num=10, i=4760, j=4770
# in analyze fn, num=10, i=4770, j=4780
# in analyze fn, num=10, i=4780, j=4790
# in analyze fn, num=10, i=4790, j=4800
# in analyze fn, num=10, i=4800, j=4810
# in analyze fn, num=10, i=4810, j=4820
# in analyze fn, num=10, i=4820, j=4830
# in analyze fn, num=10, i=4830, j=4840
# in analyze fn, num=10, i=4840, j=4850
# in analyze fn, num=10, i=4850, j=4860
# in analyze fn, num=10, i=4860, j=4870
# in analyze fn, num=10, i=4870, j=4880
# in analyze fn, num=10, i=4880, j=4890
# in analyze fn, num=10, i=4890, j=4900
# in analyze fn, num=10, i=4900, j=4910
# in analyze fn, num=10, i=4910, j=4920
# in analyze fn, num=10, i=4920, j=4930
# in analyze fn, num=10, i=4930, j=4940
# in analyze fn, num=10, i=4940, j=4950
# in analyze fn, num=10, i=4950, j=4960
# in analyze fn, num=10, i=4960, j=4970
# in analyze fn, num=10, i=4970, j=4980
# in analyze fn, num=10, i=4980, j=4990
# in analyze fn, num=10, i=4990, j=5000
# in analyze fn, num=10, i=5000, j=5010
# in analyze fn, num=10, i=5010, j=5020
# in analyze fn, num=10, i=5020, j=5030
# in analyze fn, num=10, i=5030, j=5040
# in analyze fn, num=10, i=5040, j=5050
# in analyze fn, num=10, i=5050, j=5060
# in analyze fn, num=10, i=5060, j=5070
# in analyze fn, num=10, i=5070, j=5080
# in analyze fn, num=10, i=5080, j=5090
# in analyze fn, num=10, i=5090, j=5100
# in analyze fn, num=10, i=5100, j=5110
# in analyze fn, num=10, i=5110, j=5120
# in analyze fn, num=10, i=5120, j=5130
# in analyze fn, num=10, i=5130, j=5140
# in analyze fn, num=10, i=5140, j=5150
# in analyze fn, num=10, i=5150, j=5160
# in analyze fn, num=10, i=5160, j=5170
# in analyze fn, num=10, i=5170, j=5180
# in analyze fn, num=10, i=5180, j=5190
# in analyze fn, num=10, i=5190, j=5200
# in analyze fn, num=10, i=5200, j=5210
# in analyze fn, num=10, i=5210, j=5220
# in analyze fn, num=10, i=5220, j=5230
# in analyze fn, num=10, i=5230, j=5240
# in analyze fn, num=10, i=5240, j=5250
# in analyze fn, num=10, i=5250, j=5260
# in analyze fn, num=10, i=5260, j=5270
# in analyze fn, num=10, i=5270, j=5280
# in analyze fn, num=10, i=5280, j=5290
# in analyze fn, num=10, i=5290, j=5300
# in analyze fn, num=10, i=5300, j=5310
# in analyze fn, num=10, i=5310, j=5320
# in analyze fn, num=10, i=5320, j=5330
# in analyze fn, num=10, i=5330, j=5340
# in analyze fn, num=10, i=5340, j=5350
# in analyze fn, num=10, i=5350, j=5360
# in analyze fn, num=10, i=5360, j=5370
# in analyze fn, num=10, i=5370, j=5380
# in analyze fn, num=10, i=5380, j=5390
# in analyze fn, num=10, i=5390, j=5400
# in analyze fn, num=10, i=5400, j=5410
# in analyze fn, num=10, i=5410, j=5420
# in analyze fn, num=10, i=5420, j=5430
# in analyze fn, num=10, i=5430, j=5440
# in analyze fn, num=10, i=5440, j=5450
# in analyze fn, num=10, i=5450, j=5460
# in analyze fn, num=10, i=5460, j=5470
# in analyze fn, num=10, i=5470, j=5480
# in analyze fn, num=10, i=5480, j=5490
# in analyze fn, num=10, i=5490, j=5500
# in analyze fn, num=10, i=5500, j=5510
# in analyze fn, num=10, i=5510, j=5520
# in analyze fn, num=10, i=5520, j=5530
# in analyze fn, num=10, i=5530, j=5540
# in analyze fn, num=10, i=5540, j=5550
# in analyze fn, num=10, i=5550, j=5560
# in analyze fn, num=10, i=5560, j=5570
# in analyze fn, num=10, i=5570, j=5580
# in analyze fn, num=10, i=5580, j=5590
# in analyze fn, num=10, i=5590, j=5600
# in analyze fn, num=10, i=5600, j=5610
# in analyze fn, num=10, i=5610, j=5620
# in analyze fn, num=10, i=5620, j=5630
# in analyze fn, num=10, i=5630, j=5640
# in analyze fn, num=10, i=5640, j=5650
# in analyze fn, num=10, i=5650, j=5660
# in analyze fn, num=10, i=5660, j=5670
# in analyze fn, num=10, i=5670, j=5680
# in analyze fn, num=10, i=5680, j=5690
# in analyze fn, num=10, i=5690, j=5700
# in analyze fn, num=10, i=5700, j=5710
# in analyze fn, num=10, i=5710, j=5720
# in analyze fn, num=10, i=5720, j=5730
# in analyze fn, num=10, i=5730, j=5740
# in analyze fn, num=10, i=5740, j=5750
# in analyze fn, num=10, i=5750, j=5760
# in analyze fn, num=10, i=5760, j=5770
# in analyze fn, num=10, i=5770, j=5780
# in analyze fn, num=10, i=5780, j=5790
# in analyze fn, num=10, i=5790, j=5800
# in analyze fn, num=10, i=5800, j=5810
# in analyze fn, num=10, i=5810, j=5820
# in analyze fn, num=10, i=5820, j=5830
# in analyze fn, num=10, i=5830, j=5840
# in analyze fn, num=10, i=5840, j=5850
# in analyze fn, num=10, i=5850, j=5860
# in analyze fn, num=10, i=5860, j=5870
# in analyze fn, num=10, i=5870, j=5880
# in analyze fn, num=10, i=5880, j=5890
# in analyze fn, num=10, i=5890, j=5900
# in analyze fn, num=10, i=5900, j=5910
# in analyze fn, num=10, i=5910, j=5920
# in analyze fn, num=10, i=5920, j=5930
# in analyze fn, num=10, i=5930, j=5940
# in analyze fn, num=10, i=5940, j=5950
# in analyze fn, num=10, i=5950, j=5960
# in analyze fn, num=10, i=5960, j=5970
# in analyze fn, num=10, i=5970, j=5980
# in analyze fn, num=10, i=5980, j=5990
# in analyze fn, num=10, i=5990, j=6000
# in analyze fn, num=10, i=6000, j=6010
# in analyze fn, num=10, i=6010, j=6020
# in analyze fn, num=10, i=6020, j=6030
# in analyze fn, num=10, i=6030, j=6040
# in analyze fn, num=10, i=6040, j=6050
# in analyze fn, num=10, i=6050, j=6060
# in analyze fn, num=10, i=6060, j=6070
# in analyze fn, num=10, i=6070, j=6080
# in analyze fn, num=10, i=6080, j=6090
# in analyze fn, num=10, i=6090, j=6100
# in analyze fn, num=10, i=6100, j=6110
# in analyze fn, num=10, i=6110, j=6120
# in analyze fn, num=10, i=6120, j=6130
# in analyze fn, num=10, i=6130, j=6140
# in analyze fn, num=10, i=6140, j=6150
# in analyze fn, num=10, i=6150, j=6160
# in analyze fn, num=10, i=6160, j=6170
# in analyze fn, num=10, i=6170, j=6180
# in analyze fn, num=10, i=6180, j=6190
# in analyze fn, num=10, i=6190, j=6200
# in analyze fn, num=10, i=6200, j=6210
# in analyze fn, num=10, i=6210, j=6220
# in analyze fn, num=10, i=6220, j=6230
# in analyze fn, num=10, i=6230, j=6240
# in analyze fn, num=10, i=6240, j=6250
# in analyze fn, num=10, i=6250, j=6260
# in analyze fn, num=10, i=6260, j=6270
# in analyze fn, num=10, i=6270, j=6280
# in analyze fn, num=10, i=6280, j=6290
# in analyze fn, num=10, i=6290, j=6300
# in analyze fn, num=10, i=6300, j=6310
# in analyze fn, num=10, i=6310, j=6320
# in analyze fn, num=10, i=6320, j=6330
# in analyze fn, num=10, i=6330, j=6340
# in analyze fn, num=10, i=6340, j=6350
# in analyze fn, num=10, i=6350, j=6360
# in analyze fn, num=10, i=6360, j=6370
# in analyze fn, num=10, i=6370, j=6380
# in analyze fn, num=10, i=6380, j=6390
# in analyze fn, num=10, i=6390, j=6400
# in analyze fn, num=10, i=6400, j=6410
# in analyze fn, num=10, i=6410, j=6420
# in analyze fn, num=10, i=6420, j=6430
# in analyze fn, num=10, i=6430, j=6440
# in analyze fn, num=10, i=6440, j=6450
# in analyze fn, num=10, i=6450, j=6460
# in analyze fn, num=10, i=6460, j=6470
# in analyze fn, num=10, i=6470, j=6480
# in analyze fn, num=10, i=6480, j=6490
# in analyze fn, num=10, i=6490, j=6500
# in analyze fn, num=10, i=6500, j=6510
# in analyze fn, num=10, i=6510, j=6520
# in analyze fn, num=10, i=6520, j=6530
# in analyze fn, num=10, i=6530, j=6540
# in analyze fn, num=10, i=6540, j=6550
# in analyze fn, num=10, i=6550, j=6560
# in analyze fn, num=10, i=6560, j=6570
# in analyze fn, num=10, i=6570, j=6580
# in analyze fn, num=10, i=6580, j=6590
# in analyze fn, num=10, i=6590, j=6600
# in analyze fn, num=10, i=6600, j=6610
# in analyze fn, num=10, i=6610, j=6620
# in analyze fn, num=10, i=6620, j=6630
# in analyze fn, num=10, i=6630, j=6640
# in analyze fn, num=10, i=6640, j=6650
# in analyze fn, num=10, i=6650, j=6660
# in analyze fn, num=10, i=6660, j=6670
# in analyze fn, num=10, i=6670, j=6680
# in analyze fn, num=10, i=6680, j=6690
# in analyze fn, num=10, i=6690, j=6700
# in analyze fn, num=10, i=6700, j=6710
# in analyze fn, num=10, i=6710, j=6720
# in analyze fn, num=10, i=6720, j=6730
# in analyze fn, num=10, i=6730, j=6740
# in analyze fn, num=10, i=6740, j=6750
# in analyze fn, num=10, i=6750, j=6760
# in analyze fn, num=10, i=6760, j=6770
# in analyze fn, num=10, i=6770, j=6780
# in analyze fn, num=10, i=6780, j=6790
# in analyze fn, num=10, i=6790, j=6800
# in analyze fn, num=10, i=6800, j=6810
# in analyze fn, num=10, i=6810, j=6820
# in analyze fn, num=10, i=6820, j=6830
# in analyze fn, num=10, i=6830, j=6840
# in analyze fn, num=10, i=6840, j=6850
# in analyze fn, num=10, i=6850, j=6860
# in analyze fn, num=10, i=6860, j=6870
# in analyze fn, num=10, i=6870, j=6880
# in analyze fn, num=10, i=6880, j=6890
# in analyze fn, num=10, i=6890, j=6900
# in analyze fn, num=10, i=6900, j=6910
# in analyze fn, num=10, i=6910, j=6920
# in analyze fn, num=10, i=6920, j=6930
# in analyze fn, num=10, i=6930, j=6940
# in analyze fn, num=10, i=6940, j=6950
# in analyze fn, num=10, i=6950, j=6960
# in analyze fn, num=10, i=6960, j=6970
# in analyze fn, num=10, i=6970, j=6980
# in analyze fn, num=10, i=6980, j=6990
# in analyze fn, num=10, i=6990, j=7000
# in analyze fn, num=10, i=7000, j=7010
# in analyze fn, num=10, i=7010, j=7020
# in analyze fn, num=10, i=7020, j=7030
# in analyze fn, num=10, i=7030, j=7040
# in analyze fn, num=10, i=7040, j=7050
# in analyze fn, num=10, i=7050, j=7060
# in analyze fn, num=10, i=7060, j=7070
# in analyze fn, num=10, i=7070, j=7080
# in analyze fn, num=10, i=7080, j=7090
# in analyze fn, num=10, i=7090, j=7100
# in analyze fn, num=10, i=7100, j=7110
# in analyze fn, num=10, i=7110, j=7120
# in analyze fn, num=10, i=7120, j=7130
# in analyze fn, num=10, i=7130, j=7140
# in analyze fn, num=10, i=7140, j=7150
# in analyze fn, num=10, i=7150, j=7160
# in analyze fn, num=10, i=7160, j=7170
# in analyze fn, num=10, i=7170, j=7180
# in analyze fn, num=10, i=7180, j=7190
# in analyze fn, num=10, i=7190, j=7200
# in analyze fn, num=10, i=7200, j=7210
# in analyze fn, num=10, i=7210, j=7220
# in analyze fn, num=10, i=7220, j=7230
# in analyze fn, num=10, i=7230, j=7240
# in analyze fn, num=10, i=7240, j=7250
# in analyze fn, num=10, i=7250, j=7260
# in analyze fn, num=10, i=7260, j=7270
# in analyze fn, num=10, i=7270, j=7280
# in analyze fn, num=10, i=7280, j=7290
# in analyze fn, num=10, i=7290, j=7300
# in analyze fn, num=10, i=7300, j=7310
# in analyze fn, num=10, i=7310, j=7320
# in analyze fn, num=10, i=7320, j=7330
# in analyze fn, num=10, i=7330, j=7340
# in analyze fn, num=10, i=7340, j=7350
# in analyze fn, num=10, i=7350, j=7360
# in analyze fn, num=10, i=7360, j=7370
# in analyze fn, num=10, i=7370, j=7380
# in analyze fn, num=10, i=7380, j=7390
# in analyze fn, num=10, i=7390, j=7400
# in analyze fn, num=10, i=7400, j=7410
# in analyze fn, num=10, i=7410, j=7420
# in analyze fn, num=10, i=7420, j=7430
# in analyze fn, num=10, i=7430, j=7440
# in analyze fn, num=10, i=7440, j=7450
# in analyze fn, num=10, i=7450, j=7460
# in analyze fn, num=10, i=7460, j=7470
# in analyze fn, num=10, i=7470, j=7480
# in analyze fn, num=10, i=7480, j=7490
# in analyze fn, num=10, i=7490, j=7500
# in analyze fn, num=10, i=7500, j=7510
# in analyze fn, num=10, i=7510, j=7520
# in analyze fn, num=10, i=7520, j=7530
# in analyze fn, num=10, i=7530, j=7540
# in analyze fn, num=10, i=7540, j=7550
# in analyze fn, num=10, i=7550, j=7560
# in analyze fn, num=10, i=7560, j=7570
# in analyze fn, num=10, i=7570, j=7580
# in analyze fn, num=10, i=7580, j=7590
# in analyze fn, num=10, i=7590, j=7600
# in analyze fn, num=10, i=7600, j=7610
# in analyze fn, num=10, i=7610, j=7620
# in analyze fn, num=10, i=7620, j=7630
# in analyze fn, num=10, i=7630, j=7640
# in analyze fn, num=10, i=7640, j=7650
# in analyze fn, num=10, i=7650, j=7660
# in analyze fn, num=10, i=7660, j=7670
# in analyze fn, num=10, i=7670, j=7680
# in analyze fn, num=10, i=7680, j=7690
# in analyze fn, num=10, i=7690, j=7700
# in analyze fn, num=10, i=7700, j=7710
# in analyze fn, num=10, i=7710, j=7720
# in analyze fn, num=10, i=7720, j=7730
# in analyze fn, num=10, i=7730, j=7740
# in analyze fn, num=10, i=7740, j=7750
# in analyze fn, num=10, i=7750, j=7760
# in analyze fn, num=10, i=7760, j=7770
# in analyze fn, num=10, i=7770, j=7780
# in analyze fn, num=10, i=7780, j=7790
# in analyze fn, num=10, i=7790, j=7800
# in analyze fn, num=10, i=7800, j=7810
# in analyze fn, num=10, i=7810, j=7820
# in analyze fn, num=10, i=7820, j=7830
# in analyze fn, num=10, i=7830, j=7840
# in analyze fn, num=10, i=7840, j=7850
# in analyze fn, num=10, i=7850, j=7860
# in analyze fn, num=10, i=7860, j=7870
# in analyze fn, num=10, i=7870, j=7880
# in analyze fn, num=10, i=7880, j=7890
# in analyze fn, num=10, i=7890, j=7900
# in analyze fn, num=10, i=7900, j=7910
# in analyze fn, num=10, i=7910, j=7920
# in analyze fn, num=10, i=7920, j=7930
# in analyze fn, num=10, i=7930, j=7940
# in analyze fn, num=10, i=7940, j=7950
# in analyze fn, num=10, i=7950, j=7960
# in analyze fn, num=10, i=7960, j=7970
# in analyze fn, num=10, i=7970, j=7980
# in analyze fn, num=10, i=7980, j=7990
# in analyze fn, num=10, i=7990, j=8000
# in analyze fn, num=10, i=8000, j=8010
# in analyze fn, num=10, i=8010, j=8020
# in analyze fn, num=10, i=8020, j=8030
# in analyze fn, num=10, i=8030, j=8040
# in analyze fn, num=10, i=8040, j=8050
# in analyze fn, num=10, i=8050, j=8060
# in analyze fn, num=10, i=8060, j=8070
# in analyze fn, num=10, i=8070, j=8080
# in analyze fn, num=10, i=8080, j=8090
# in analyze fn, num=10, i=8090, j=8100
# in analyze fn, num=10, i=8100, j=8110
# in analyze fn, num=10, i=8110, j=8120
# in analyze fn, num=10, i=8120, j=8130
# in analyze fn, num=10, i=8130, j=8140
# in analyze fn, num=10, i=8140, j=8150
# in analyze fn, num=10, i=8150, j=8160
# in analyze fn, num=10, i=8160, j=8170
# in analyze fn, num=10, i=8170, j=8180
# in analyze fn, num=10, i=8180, j=8190
# in analyze fn, num=10, i=8190, j=8200
# in analyze fn, num=10, i=8200, j=8210
# in analyze fn, num=10, i=8210, j=8220
# in analyze fn, num=10, i=8220, j=8230
# in analyze fn, num=10, i=8230, j=8240
# in analyze fn, num=10, i=8240, j=8250
# in analyze fn, num=10, i=8250, j=8260
# in analyze fn, num=10, i=8260, j=8270
# in analyze fn, num=10, i=8270, j=8280
# in analyze fn, num=10, i=8280, j=8290
# in analyze fn, num=10, i=8290, j=8300
# in analyze fn, num=10, i=8300, j=8310
# in analyze fn, num=10, i=8310, j=8320
# in analyze fn, num=10, i=8320, j=8330
# in analyze fn, num=10, i=8330, j=8340
# in analyze fn, num=10, i=8340, j=8350
# in analyze fn, num=10, i=8350, j=8360
# in analyze fn, num=10, i=8360, j=8370
# in analyze fn, num=10, i=8370, j=8380
# in analyze fn, num=10, i=8380, j=8390
# in analyze fn, num=10, i=8390, j=8400
# in analyze fn, num=10, i=8400, j=8410
# in analyze fn, num=10, i=8410, j=8420
# in analyze fn, num=10, i=8420, j=8430
# in analyze fn, num=10, i=8430, j=8440
# in analyze fn, num=10, i=8440, j=8450
# in analyze fn, num=10, i=8450, j=8460
# in analyze fn, num=10, i=8460, j=8470
# in analyze fn, num=10, i=8470, j=8480
# in analyze fn, num=10, i=8480, j=8490
# in analyze fn, num=10, i=8490, j=8500
# in analyze fn, num=10, i=8500, j=8510
# in analyze fn, num=10, i=8510, j=8520
# in analyze fn, num=10, i=8520, j=8530
# in analyze fn, num=10, i=8530, j=8540
# in analyze fn, num=10, i=8540, j=8550
# in analyze fn, num=10, i=8550, j=8560
# in analyze fn, num=10, i=8560, j=8570
# in analyze fn, num=10, i=8570, j=8580
# in analyze fn, num=10, i=8580, j=8590
# in analyze fn, num=10, i=8590, j=8600
# in analyze fn, num=10, i=8600, j=8610
# in analyze fn, num=10, i=8610, j=8620
# in analyze fn, num=10, i=8620, j=8630
# in analyze fn, num=10, i=8630, j=8640
# in analyze fn, num=10, i=8640, j=8650
# in analyze fn, num=10, i=8650, j=8660
# in analyze fn, num=10, i=8660, j=8670
# in analyze fn, num=10, i=8670, j=8680
# in analyze fn, num=10, i=8680, j=8690
# in analyze fn, num=10, i=8690, j=8700
# in analyze fn, num=10, i=8700, j=8710
# in analyze fn, num=10, i=8710, j=8720
# in analyze fn, num=10, i=8720, j=8730
# in analyze fn, num=10, i=8730, j=8740
# in analyze fn, num=10, i=8740, j=8750
# in analyze fn, num=10, i=8750, j=8760
# in analyze fn, num=10, i=8760, j=8770
# in analyze fn, num=10, i=8770, j=8780
# in analyze fn, num=10, i=8780, j=8790
# in analyze fn, num=10, i=8790, j=8800
# in analyze fn, num=10, i=8800, j=8810
# in analyze fn, num=10, i=8810, j=8820
# in analyze fn, num=10, i=8820, j=8830
# in analyze fn, num=10, i=8830, j=8840
# in analyze fn, num=10, i=8840, j=8850
# in analyze fn, num=10, i=8850, j=8860
# in analyze fn, num=10, i=8860, j=8870
# in analyze fn, num=10, i=8870, j=8880
# in analyze fn, num=10, i=8880, j=8890
# in analyze fn, num=10, i=8890, j=8900
# in analyze fn, num=10, i=8900, j=8910
# in analyze fn, num=10, i=8910, j=8920
# in analyze fn, num=10, i=8920, j=8930
# in analyze fn, num=10, i=8930, j=8940
# in analyze fn, num=10, i=8940, j=8950
# in analyze fn, num=10, i=8950, j=8960
# in analyze fn, num=10, i=8960, j=8970
# in analyze fn, num=10, i=8970, j=8980
# in analyze fn, num=10, i=8980, j=8990
# in analyze fn, num=10, i=8990, j=9000
# in analyze fn, num=10, i=9000, j=9010
# in analyze fn, num=10, i=9010, j=9020
# in analyze fn, num=10, i=9020, j=9030
# in analyze fn, num=10, i=9030, j=9040
# in analyze fn, num=10, i=9040, j=9050
# in analyze fn, num=10, i=9050, j=9060
# in analyze fn, num=10, i=9060, j=9070
# in analyze fn, num=10, i=9070, j=9080
# in analyze fn, num=10, i=9080, j=9090
# in analyze fn, num=10, i=9090, j=9100
# in analyze fn, num=10, i=9100, j=9110
# in analyze fn, num=10, i=9110, j=9120
# in analyze fn, num=10, i=9120, j=9130
# in analyze fn, num=10, i=9130, j=9140
# in analyze fn, num=10, i=9140, j=9150
# in analyze fn, num=10, i=9150, j=9160
# in analyze fn, num=10, i=9160, j=9170
# in analyze fn, num=10, i=9170, j=9180
# in analyze fn, num=10, i=9180, j=9190
# in analyze fn, num=10, i=9190, j=9200
# in analyze fn, num=10, i=9200, j=9210
# in analyze fn, num=10, i=9210, j=9220
# in analyze fn, num=10, i=9220, j=9230
# in analyze fn, num=10, i=9230, j=9240
# in analyze fn, num=10, i=9240, j=9250
# in analyze fn, num=10, i=9250, j=9260
# in analyze fn, num=10, i=9260, j=9270
# in analyze fn, num=10, i=9270, j=9280
# in analyze fn, num=10, i=9280, j=9290
# in analyze fn, num=10, i=9290, j=9300
# in analyze fn, num=10, i=9300, j=9310
# in analyze fn, num=10, i=9310, j=9320
# in analyze fn, num=10, i=9320, j=9330
# in analyze fn, num=10, i=9330, j=9340
# in analyze fn, num=10, i=9340, j=9350
# in analyze fn, num=10, i=9350, j=9360
# in analyze fn, num=10, i=9360, j=9370
# in analyze fn, num=50, i=0, j=50
# in analyze fn, num=50, i=50, j=100
# in analyze fn, num=50, i=100, j=150
# in analyze fn, num=50, i=150, j=200
# in analyze fn, num=50, i=200, j=250
# in analyze fn, num=50, i=250, j=300
# in analyze fn, num=50, i=300, j=350
# in analyze fn, num=50, i=350, j=400
# in analyze fn, num=50, i=400, j=450
# in analyze fn, num=50, i=450, j=500
# in analyze fn, num=50, i=500, j=550
# in analyze fn, num=50, i=550, j=600
# in analyze fn, num=50, i=600, j=650
# in analyze fn, num=50, i=650, j=700
# in analyze fn, num=50, i=700, j=750
# in analyze fn, num=50, i=750, j=800
# in analyze fn, num=50, i=800, j=850
# in analyze fn, num=50, i=850, j=900
# in analyze fn, num=50, i=900, j=950
# in analyze fn, num=50, i=950, j=1000
# in analyze fn, num=50, i=1000, j=1050
# in analyze fn, num=50, i=1050, j=1100
# in analyze fn, num=50, i=1100, j=1150
# in analyze fn, num=50, i=1150, j=1200
# in analyze fn, num=50, i=1200, j=1250
# in analyze fn, num=50, i=1250, j=1300
# in analyze fn, num=50, i=1300, j=1350
# in analyze fn, num=50, i=1350, j=1400
# in analyze fn, num=50, i=1400, j=1450
# in analyze fn, num=50, i=1450, j=1500
# in analyze fn, num=50, i=1500, j=1550
# in analyze fn, num=50, i=1550, j=1600
# in analyze fn, num=50, i=1600, j=1650
# in analyze fn, num=50, i=1650, j=1700
# in analyze fn, num=50, i=1700, j=1750
# in analyze fn, num=50, i=1750, j=1800
# in analyze fn, num=50, i=1800, j=1850
# in analyze fn, num=50, i=1850, j=1900
# in analyze fn, num=50, i=1900, j=1950
# in analyze fn, num=50, i=1950, j=2000
# in analyze fn, num=50, i=2000, j=2050
# in analyze fn, num=50, i=2050, j=2100
# in analyze fn, num=50, i=2100, j=2150
# in analyze fn, num=50, i=2150, j=2200
# in analyze fn, num=50, i=2200, j=2250
# in analyze fn, num=50, i=2250, j=2300
# in analyze fn, num=50, i=2300, j=2350
# in analyze fn, num=50, i=2350, j=2400
# in analyze fn, num=50, i=2400, j=2450
# in analyze fn, num=50, i=2450, j=2500
# in analyze fn, num=50, i=2500, j=2550
# in analyze fn, num=50, i=2550, j=2600
# in analyze fn, num=50, i=2600, j=2650
# in analyze fn, num=50, i=2650, j=2700
# in analyze fn, num=50, i=2700, j=2750
# in analyze fn, num=50, i=2750, j=2800
# in analyze fn, num=50, i=2800, j=2850
# in analyze fn, num=50, i=2850, j=2900
# in analyze fn, num=50, i=2900, j=2950
# in analyze fn, num=50, i=2950, j=3000
# in analyze fn, num=50, i=3000, j=3050
# in analyze fn, num=50, i=3050, j=3100
# in analyze fn, num=50, i=3100, j=3150
# in analyze fn, num=50, i=3150, j=3200
# in analyze fn, num=50, i=3200, j=3250
# in analyze fn, num=50, i=3250, j=3300
# in analyze fn, num=50, i=3300, j=3350
# in analyze fn, num=50, i=3350, j=3400
# in analyze fn, num=50, i=3400, j=3450
# in analyze fn, num=50, i=3450, j=3500
# in analyze fn, num=50, i=3500, j=3550
# in analyze fn, num=50, i=3550, j=3600
# in analyze fn, num=50, i=3600, j=3650
# in analyze fn, num=50, i=3650, j=3700
# in analyze fn, num=50, i=3700, j=3750
# in analyze fn, num=50, i=3750, j=3800
# in analyze fn, num=50, i=3800, j=3850
# in analyze fn, num=50, i=3850, j=3900
# in analyze fn, num=50, i=3900, j=3950
# in analyze fn, num=50, i=3950, j=4000
# in analyze fn, num=50, i=4000, j=4050
# in analyze fn, num=50, i=4050, j=4100
# in analyze fn, num=50, i=4100, j=4150
# in analyze fn, num=50, i=4150, j=4200
# in analyze fn, num=50, i=4200, j=4250
# in analyze fn, num=50, i=4250, j=4300
# in analyze fn, num=50, i=4300, j=4350
# in analyze fn, num=50, i=4350, j=4400
# in analyze fn, num=50, i=4400, j=4450
# in analyze fn, num=50, i=4450, j=4500
# in analyze fn, num=50, i=4500, j=4550
# in analyze fn, num=50, i=4550, j=4600
# in analyze fn, num=50, i=4600, j=4650
# in analyze fn, num=50, i=4650, j=4700
# in analyze fn, num=50, i=4700, j=4750
# in analyze fn, num=50, i=4750, j=4800
# in analyze fn, num=50, i=4800, j=4850
# in analyze fn, num=50, i=4850, j=4900
# in analyze fn, num=50, i=4900, j=4950
# in analyze fn, num=50, i=4950, j=5000
# in analyze fn, num=50, i=5000, j=5050
# in analyze fn, num=50, i=5050, j=5100
# in analyze fn, num=50, i=5100, j=5150
# in analyze fn, num=50, i=5150, j=5200
# in analyze fn, num=50, i=5200, j=5250
# in analyze fn, num=50, i=5250, j=5300
# in analyze fn, num=50, i=5300, j=5350
# in analyze fn, num=50, i=5350, j=5400
# in analyze fn, num=50, i=5400, j=5450
# in analyze fn, num=50, i=5450, j=5500
# in analyze fn, num=50, i=5500, j=5550
# in analyze fn, num=50, i=5550, j=5600
# in analyze fn, num=50, i=5600, j=5650
# in analyze fn, num=50, i=5650, j=5700
# in analyze fn, num=50, i=5700, j=5750
# in analyze fn, num=50, i=5750, j=5800
# in analyze fn, num=50, i=5800, j=5850
# in analyze fn, num=50, i=5850, j=5900
# in analyze fn, num=50, i=5900, j=5950
# in analyze fn, num=50, i=5950, j=6000
# in analyze fn, num=50, i=6000, j=6050
# in analyze fn, num=50, i=6050, j=6100
# in analyze fn, num=50, i=6100, j=6150
# in analyze fn, num=50, i=6150, j=6200
# in analyze fn, num=50, i=6200, j=6250
# in analyze fn, num=50, i=6250, j=6300
# in analyze fn, num=50, i=6300, j=6350
# in analyze fn, num=50, i=6350, j=6400
# in analyze fn, num=50, i=6400, j=6450
# in analyze fn, num=50, i=6450, j=6500
# in analyze fn, num=50, i=6500, j=6550
# in analyze fn, num=50, i=6550, j=6600
# in analyze fn, num=50, i=6600, j=6650
# in analyze fn, num=50, i=6650, j=6700
# in analyze fn, num=50, i=6700, j=6750
# in analyze fn, num=50, i=6750, j=6800
# in analyze fn, num=50, i=6800, j=6850
# in analyze fn, num=50, i=6850, j=6900
# in analyze fn, num=50, i=6900, j=6950
# in analyze fn, num=50, i=6950, j=7000
# in analyze fn, num=50, i=7000, j=7050
# in analyze fn, num=50, i=7050, j=7100
# in analyze fn, num=50, i=7100, j=7150
# in analyze fn, num=50, i=7150, j=7200
# in analyze fn, num=50, i=7200, j=7250
# in analyze fn, num=50, i=7250, j=7300
# in analyze fn, num=50, i=7300, j=7350
# in analyze fn, num=50, i=7350, j=7400
# in analyze fn, num=50, i=7400, j=7450
# in analyze fn, num=50, i=7450, j=7500
# in analyze fn, num=50, i=7500, j=7550
# in analyze fn, num=50, i=7550, j=7600
# in analyze fn, num=50, i=7600, j=7650
# in analyze fn, num=50, i=7650, j=7700
# in analyze fn, num=50, i=7700, j=7750
# in analyze fn, num=50, i=7750, j=7800
# in analyze fn, num=50, i=7800, j=7850
# in analyze fn, num=50, i=7850, j=7900
# in analyze fn, num=50, i=7900, j=7950
# in analyze fn, num=50, i=7950, j=8000
# in analyze fn, num=50, i=8000, j=8050
# in analyze fn, num=50, i=8050, j=8100
# in analyze fn, num=50, i=8100, j=8150
# in analyze fn, num=50, i=8150, j=8200
# in analyze fn, num=50, i=8200, j=8250
# in analyze fn, num=50, i=8250, j=8300
# in analyze fn, num=50, i=8300, j=8350
# in analyze fn, num=50, i=8350, j=8400
# in analyze fn, num=50, i=8400, j=8450
# in analyze fn, num=50, i=8450, j=8500
# in analyze fn, num=50, i=8500, j=8550
# in analyze fn, num=50, i=8550, j=8600
# in analyze fn, num=50, i=8600, j=8650
# in analyze fn, num=50, i=8650, j=8700
# in analyze fn, num=50, i=8700, j=8750
# in analyze fn, num=50, i=8750, j=8800
# in analyze fn, num=50, i=8800, j=8850
# in analyze fn, num=50, i=8850, j=8900
# in analyze fn, num=50, i=8900, j=8950
# in analyze fn, num=50, i=8950, j=9000
# in analyze fn, num=50, i=9000, j=9050
# in analyze fn, num=50, i=9050, j=9100
# in analyze fn, num=50, i=9100, j=9150
# in analyze fn, num=50, i=9150, j=9200
# in analyze fn, num=50, i=9200, j=9250
# in analyze fn, num=50, i=9250, j=9300
# in analyze fn, num=50, i=9300, j=9350
# in analyze fn, num=100, i=0, j=100
# in analyze fn, num=100, i=100, j=200
# in analyze fn, num=100, i=200, j=300
# in analyze fn, num=100, i=300, j=400
# in analyze fn, num=100, i=400, j=500
# in analyze fn, num=100, i=500, j=600
# in analyze fn, num=100, i=600, j=700
# in analyze fn, num=100, i=700, j=800
# in analyze fn, num=100, i=800, j=900
# in analyze fn, num=100, i=900, j=1000
# in analyze fn, num=100, i=1000, j=1100
# in analyze fn, num=100, i=1100, j=1200
# in analyze fn, num=100, i=1200, j=1300
# in analyze fn, num=100, i=1300, j=1400
# in analyze fn, num=100, i=1400, j=1500
# in analyze fn, num=100, i=1500, j=1600
# in analyze fn, num=100, i=1600, j=1700
# in analyze fn, num=100, i=1700, j=1800
# in analyze fn, num=100, i=1800, j=1900
# in analyze fn, num=100, i=1900, j=2000
# in analyze fn, num=100, i=2000, j=2100
# in analyze fn, num=100, i=2100, j=2200
# in analyze fn, num=100, i=2200, j=2300
# in analyze fn, num=100, i=2300, j=2400
# in analyze fn, num=100, i=2400, j=2500
# in analyze fn, num=100, i=2500, j=2600
# in analyze fn, num=100, i=2600, j=2700
# in analyze fn, num=100, i=2700, j=2800
# in analyze fn, num=100, i=2800, j=2900
# in analyze fn, num=100, i=2900, j=3000
# in analyze fn, num=100, i=3000, j=3100
# in analyze fn, num=100, i=3100, j=3200
# in analyze fn, num=100, i=3200, j=3300
# in analyze fn, num=100, i=3300, j=3400
# in analyze fn, num=100, i=3400, j=3500
# in analyze fn, num=100, i=3500, j=3600
# in analyze fn, num=100, i=3600, j=3700
# in analyze fn, num=100, i=3700, j=3800
# in analyze fn, num=100, i=3800, j=3900
# in analyze fn, num=100, i=3900, j=4000
# in analyze fn, num=100, i=4000, j=4100
# in analyze fn, num=100, i=4100, j=4200
# in analyze fn, num=100, i=4200, j=4300
# in analyze fn, num=100, i=4300, j=4400
# in analyze fn, num=100, i=4400, j=4500
# in analyze fn, num=100, i=4500, j=4600
# in analyze fn, num=100, i=4600, j=4700
# in analyze fn, num=100, i=4700, j=4800
# in analyze fn, num=100, i=4800, j=4900
# in analyze fn, num=100, i=4900, j=5000
# in analyze fn, num=100, i=5000, j=5100
# in analyze fn, num=100, i=5100, j=5200
# in analyze fn, num=100, i=5200, j=5300
# in analyze fn, num=100, i=5300, j=5400
# in analyze fn, num=100, i=5400, j=5500
# in analyze fn, num=100, i=5500, j=5600
# in analyze fn, num=100, i=5600, j=5700
# in analyze fn, num=100, i=5700, j=5800
# in analyze fn, num=100, i=5800, j=5900
# in analyze fn, num=100, i=5900, j=6000
# in analyze fn, num=100, i=6000, j=6100
# in analyze fn, num=100, i=6100, j=6200
# in analyze fn, num=100, i=6200, j=6300
# in analyze fn, num=100, i=6300, j=6400
# in analyze fn, num=100, i=6400, j=6500
# in analyze fn, num=100, i=6500, j=6600
# in analyze fn, num=100, i=6600, j=6700
# in analyze fn, num=100, i=6700, j=6800
# in analyze fn, num=100, i=6800, j=6900
# in analyze fn, num=100, i=6900, j=7000
# in analyze fn, num=100, i=7000, j=7100
# in analyze fn, num=100, i=7100, j=7200
# in analyze fn, num=100, i=7200, j=7300
# in analyze fn, num=100, i=7300, j=7400
# in analyze fn, num=100, i=7400, j=7500
# in analyze fn, num=100, i=7500, j=7600
# in analyze fn, num=100, i=7600, j=7700
# in analyze fn, num=100, i=7700, j=7800
# in analyze fn, num=100, i=7800, j=7900
# in analyze fn, num=100, i=7900, j=8000
# in analyze fn, num=100, i=8000, j=8100
# in analyze fn, num=100, i=8100, j=8200
# in analyze fn, num=100, i=8200, j=8300
# in analyze fn, num=100, i=8300, j=8400
# in analyze fn, num=100, i=8400, j=8500
# in analyze fn, num=100, i=8500, j=8600
# in analyze fn, num=100, i=8600, j=8700
# in analyze fn, num=100, i=8700, j=8800
# in analyze fn, num=100, i=8800, j=8900
# in analyze fn, num=100, i=8900, j=9000
# in analyze fn, num=100, i=9000, j=9100
# in analyze fn, num=100, i=9100, j=9200
# in analyze fn, num=100, i=9200, j=9300
# in analyze fn, num=250, i=0, j=250
# in analyze fn, num=250, i=250, j=500
# in analyze fn, num=250, i=500, j=750
# in analyze fn, num=250, i=750, j=1000
# in analyze fn, num=250, i=1000, j=1250
# in analyze fn, num=250, i=1250, j=1500
# in analyze fn, num=250, i=1500, j=1750
# in analyze fn, num=250, i=1750, j=2000
# in analyze fn, num=250, i=2000, j=2250
# in analyze fn, num=250, i=2250, j=2500
# in analyze fn, num=250, i=2500, j=2750
# in analyze fn, num=250, i=2750, j=3000
# in analyze fn, num=250, i=3000, j=3250
# in analyze fn, num=250, i=3250, j=3500
# in analyze fn, num=250, i=3500, j=3750
# in analyze fn, num=250, i=3750, j=4000
# in analyze fn, num=250, i=4000, j=4250
# in analyze fn, num=250, i=4250, j=4500
# in analyze fn, num=250, i=4500, j=4750
# in analyze fn, num=250, i=4750, j=5000
# in analyze fn, num=250, i=5000, j=5250
# in analyze fn, num=250, i=5250, j=5500
# in analyze fn, num=250, i=5500, j=5750
# in analyze fn, num=250, i=5750, j=6000
# in analyze fn, num=250, i=6000, j=6250
# in analyze fn, num=250, i=6250, j=6500
# in analyze fn, num=250, i=6500, j=6750
# in analyze fn, num=250, i=6750, j=7000
# in analyze fn, num=250, i=7000, j=7250
# in analyze fn, num=250, i=7250, j=7500
# in analyze fn, num=250, i=7500, j=7750
# in analyze fn, num=250, i=7750, j=8000
# in analyze fn, num=250, i=8000, j=8250
# in analyze fn, num=250, i=8250, j=8500
# in analyze fn, num=250, i=8500, j=8750
# in analyze fn, num=250, i=8750, j=9000
# in analyze fn, num=250, i=9000, j=9250
# in analyze fn, num=500, i=0, j=500
# in analyze fn, num=500, i=500, j=1000
# in analyze fn, num=500, i=1000, j=1500
# in analyze fn, num=500, i=1500, j=2000
# in analyze fn, num=500, i=2000, j=2500
# in analyze fn, num=500, i=2500, j=3000
# in analyze fn, num=500, i=3000, j=3500
# in analyze fn, num=500, i=3500, j=4000
# in analyze fn, num=500, i=4000, j=4500
# in analyze fn, num=500, i=4500, j=5000
# in analyze fn, num=500, i=5000, j=5500
# in analyze fn, num=500, i=5500, j=6000
# in analyze fn, num=500, i=6000, j=6500
# in analyze fn, num=500, i=6500, j=7000
# in analyze fn, num=500, i=7000, j=7500
# in analyze fn, num=500, i=7500, j=8000
# in analyze fn, num=500, i=8000, j=8500
# in analyze fn, num=500, i=8500, j=9000
# in analyze fn, num=750, i=0, j=750
# in analyze fn, num=750, i=750, j=1500
# in analyze fn, num=750, i=1500, j=2250
# in analyze fn, num=750, i=2250, j=3000
# in analyze fn, num=750, i=3000, j=3750
# in analyze fn, num=750, i=3750, j=4500
# in analyze fn, num=750, i=4500, j=5250
# in analyze fn, num=750, i=5250, j=6000
# in analyze fn, num=750, i=6000, j=6750
# in analyze fn, num=750, i=6750, j=7500
# in analyze fn, num=750, i=7500, j=8250
# in analyze fn, num=750, i=8250, j=9000
# in analyze fn, num=1000, i=0, j=1000
# in analyze fn, num=1000, i=1000, j=2000
# in analyze fn, num=1000, i=2000, j=3000
# in analyze fn, num=1000, i=3000, j=4000
# in analyze fn, num=1000, i=4000, j=5000
# in analyze fn, num=1000, i=5000, j=6000
# in analyze fn, num=1000, i=6000, j=7000
# in analyze fn, num=1000, i=7000, j=8000
# in analyze fn, num=1000, i=8000, j=9000
# in analyze fn, num=5000, i=0, j=5000
